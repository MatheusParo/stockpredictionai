# %%
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import time
import datetime


STOCK = "TSLA"

def parser(x):
    return datetime.datetime.strptime(x,'%Y-%m-%d')

style.use('ggplot')
df = pd.read_csv('stock_dfs/{}.csv'.format(STOCK), parse_dates = True, index_col=0)
print(df.head(200))
df['100ma'] = df[STOCK].rolling(window=100, min_periods=0).mean()
df['50ma'] = df[STOCK].rolling(window=50, min_periods=0).mean()
df['10ma'] = df[STOCK].rolling(window=10, min_periods=0).mean()

ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
#ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex = ax1)

df.time = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df.set_index(['Date'],inplace=True)
df.plot()


ax1.plot(df.index, df[STOCK])
ax1.plot(df.index,df[STOCK])
ax1.plot(df.index,df[STOCK])
#ax2.bar(df.index, df['Volume'])
plt.show()
# Out:
#            Date      TSLA
# 0    2010-06-29  4.778000
# 1    2010-06-30  4.772000
# 2    2010-07-01  4.645333
# 3    2010-07-02  4.444000
# 4    2010-07-06  4.199600
# ..          ...       ...
# 195  2011-04-06  5.325260
# 196  2011-04-07  5.320060
# 197  2011-04-08  5.311440
# 198  2011-04-11  5.302640
# 199  2011-04-12  5.292960
#
# [200 rows x 2 columns]
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:2019: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
pwd
# Out:
# '/Users/Matheus/Desktop/stockpredictionai'
